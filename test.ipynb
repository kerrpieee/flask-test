# %%
import requests
from bs4 import BeautifulSoup

# %%
url="https://histock.tw/index"

# %%
resp=requests.get(url)
resp
# Out:
# <Response [200]>

# %%
url="https://data.moenv.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=JSON"

# %%
datas=requests.get(url).json()["records"]
datas
# Out:
# [{'site': '大城',
#   'county': '彰化縣',
#   'pm25': '2',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '富貴角',
#   'county': '新北市',
#   'pm25': '4',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '麥寮',
#   'county': '雲林縣',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '關山',
#   'county': '臺東縣',
#   'pm25': '1',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬公',
#   'county': '澎湖縣',
#   'pm25': '0',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '金門',
#   'county': '金門縣',
#   'pm25': '21',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬祖',
#   'county': '連江縣',
#   'pm25': '12',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '埔里',
#   'county': '南投縣',
#   'pm25': '7',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '復興',
#   'county': '高雄市',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '永和',
#   'county': '新北市',
#   'pm25': '6',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹山',
#   'county': '南投縣',
#   'pm25': '6',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中壢',
#   'county': '桃園市',
#   'pm25': '3',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三重',
#   'county': '新北市',
#   'pm25': '12',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '冬山',
#   'county': '宜蘭縣',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '宜蘭',
#   'county': '宜蘭縣',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '陽明',
#   'county': '臺北市',
#   'pm25': '0',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '花蓮',
#   'county': '花蓮縣',
#   'pm25': '1',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺東',
#   'county': '臺東縣',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '恆春',
#   'county': '屏東縣',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '潮州',
#   'county': '屏東縣',
#   'pm25': '1',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '屏東',
#   'county': '屏東縣',
#   'pm25': '0',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '小港',
#   'county': '高雄市',
#   'pm25': '2',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前鎮',
#   'county': '高雄市',
#   'pm25': '6',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前金',
#   'county': '高雄市',
#   'pm25': '4',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '左營',
#   'county': '高雄市',
#   'pm25': '7',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '楠梓',
#   'county': '高雄市',
#   'pm25': '1',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林園',
#   'county': '高雄市',
#   'pm25': '10',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大寮',
#   'county': '高雄市',
#   'pm25': '13',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '鳳山',
#   'county': '高雄市',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '仁武',
#   'county': '高雄市',
#   'pm25': '10',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '橋頭',
#   'county': '高雄市',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '美濃',
#   'county': '高雄市',
#   'pm25': '2',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺南',
#   'county': '臺南市',
#   'pm25': '3',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '安南',
#   'county': '臺南市',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '善化',
#   'county': '臺南市',
#   'pm25': '6',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新營',
#   'county': '臺南市',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '嘉義',
#   'county': '嘉義市',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺西',
#   'county': '雲林縣',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '朴子',
#   'county': '嘉義縣',
#   'pm25': '1',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新港',
#   'county': '嘉義縣',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '崙背',
#   'county': '雲林縣',
#   'pm25': '7',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '斗六',
#   'county': '雲林縣',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '南投',
#   'county': '南投縣',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '二林',
#   'county': '彰化縣',
#   'pm25': '4',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '線西',
#   'county': '彰化縣',
#   'pm25': '6',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '彰化',
#   'county': '彰化縣',
#   'pm25': '4',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '西屯',
#   'county': '臺中市',
#   'pm25': '4',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '忠明',
#   'county': '臺中市',
#   'pm25': '3',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大里',
#   'county': '臺中市',
#   'pm25': '7',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '沙鹿',
#   'county': '臺中市',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '豐原',
#   'county': '臺中市',
#   'pm25': '2',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三義',
#   'county': '苗栗縣',
#   'pm25': '2',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '苗栗',
#   'county': '苗栗縣',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '頭份',
#   'county': '苗栗縣',
#   'pm25': '7',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新竹',
#   'county': '新竹市',
#   'pm25': '3',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹東',
#   'county': '新竹縣',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '湖口',
#   'county': '新竹縣',
#   'pm25': '0',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '龍潭',
#   'county': '桃園市',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '平鎮',
#   'county': '桃園市',
#   'pm25': '4',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '觀音',
#   'county': '桃園市',
#   'pm25': '2',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大園',
#   'county': '桃園市',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '桃園',
#   'county': '桃園市',
#   'pm25': '0',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大同',
#   'county': '臺北市',
#   'pm25': '13',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '松山',
#   'county': '臺北市',
#   'pm25': '6',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '古亭',
#   'county': '臺北市',
#   'pm25': '6',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬華',
#   'county': '臺北市',
#   'pm25': '9',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中山',
#   'county': '臺北市',
#   'pm25': '7',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '士林',
#   'county': '臺北市',
#   'pm25': '1',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '淡水',
#   'county': '新北市',
#   'pm25': '6',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林口',
#   'county': '新北市',
#   'pm25': '1',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '菜寮',
#   'county': '新北市',
#   'pm25': '10',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新莊',
#   'county': '新北市',
#   'pm25': '7',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '板橋',
#   'county': '新北市',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '土城',
#   'county': '新北市',
#   'pm25': '4',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新店',
#   'county': '新北市',
#   'pm25': '12',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬里',
#   'county': '新北市',
#   'pm25': '3',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '汐止',
#   'county': '新北市',
#   'pm25': '8',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'},
#  {'site': '基隆',
#   'county': '基隆市',
#   'pm25': '5',
#   'datacreationdate': '2024-09-21 10:00',
#   'itemunit': 'μg/m3'}]

# %%
columns=list(datas[0].keys())
columns
# Out:
# ['site', 'county', 'pm25', 'datacreationdate', 'itemunit']

# %%
values=[]
for data in datas:
    values.append(list(data.values()))
values
# Out:
# [['大城', '彰化縣', '2', '2024-09-21 10:00', 'μg/m3'],
#  ['富貴角', '新北市', '4', '2024-09-21 10:00', 'μg/m3'],
#  ['麥寮', '雲林縣', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['關山', '臺東縣', '1', '2024-09-21 10:00', 'μg/m3'],
#  ['馬公', '澎湖縣', '0', '2024-09-21 10:00', 'μg/m3'],
#  ['金門', '金門縣', '21', '2024-09-21 10:00', 'μg/m3'],
#  ['馬祖', '連江縣', '12', '2024-09-21 10:00', 'μg/m3'],
#  ['埔里', '南投縣', '7', '2024-09-21 10:00', 'μg/m3'],
#  ['復興', '高雄市', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['永和', '新北市', '6', '2024-09-21 10:00', 'μg/m3'],
#  ['竹山', '南投縣', '6', '2024-09-21 10:00', 'μg/m3'],
#  ['中壢', '桃園市', '3', '2024-09-21 10:00', 'μg/m3'],
#  ['三重', '新北市', '12', '2024-09-21 10:00', 'μg/m3'],
#  ['冬山', '宜蘭縣', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['宜蘭', '宜蘭縣', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['陽明', '臺北市', '0', '2024-09-21 10:00', 'μg/m3'],
#  ['花蓮', '花蓮縣', '1', '2024-09-21 10:00', 'μg/m3'],
#  ['臺東', '臺東縣', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['恆春', '屏東縣', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['潮州', '屏東縣', '1', '2024-09-21 10:00', 'μg/m3'],
#  ['屏東', '屏東縣', '0', '2024-09-21 10:00', 'μg/m3'],
#  ['小港', '高雄市', '2', '2024-09-21 10:00', 'μg/m3'],
#  ['前鎮', '高雄市', '6', '2024-09-21 10:00', 'μg/m3'],
#  ['前金', '高雄市', '4', '2024-09-21 10:00', 'μg/m3'],
#  ['左營', '高雄市', '7', '2024-09-21 10:00', 'μg/m3'],
#  ['楠梓', '高雄市', '1', '2024-09-21 10:00', 'μg/m3'],
#  ['林園', '高雄市', '10', '2024-09-21 10:00', 'μg/m3'],
#  ['大寮', '高雄市', '13', '2024-09-21 10:00', 'μg/m3'],
#  ['鳳山', '高雄市', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['仁武', '高雄市', '10', '2024-09-21 10:00', 'μg/m3'],
#  ['橋頭', '高雄市', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['美濃', '高雄市', '2', '2024-09-21 10:00', 'μg/m3'],
#  ['臺南', '臺南市', '3', '2024-09-21 10:00', 'μg/m3'],
#  ['安南', '臺南市', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['善化', '臺南市', '6', '2024-09-21 10:00', 'μg/m3'],
#  ['新營', '臺南市', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['嘉義', '嘉義市', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['臺西', '雲林縣', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['朴子', '嘉義縣', '1', '2024-09-21 10:00', 'μg/m3'],
#  ['新港', '嘉義縣', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['崙背', '雲林縣', '7', '2024-09-21 10:00', 'μg/m3'],
#  ['斗六', '雲林縣', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['南投', '南投縣', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['二林', '彰化縣', '4', '2024-09-21 10:00', 'μg/m3'],
#  ['線西', '彰化縣', '6', '2024-09-21 10:00', 'μg/m3'],
#  ['彰化', '彰化縣', '4', '2024-09-21 10:00', 'μg/m3'],
#  ['西屯', '臺中市', '4', '2024-09-21 10:00', 'μg/m3'],
#  ['忠明', '臺中市', '3', '2024-09-21 10:00', 'μg/m3'],
#  ['大里', '臺中市', '7', '2024-09-21 10:00', 'μg/m3'],
#  ['沙鹿', '臺中市', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['豐原', '臺中市', '2', '2024-09-21 10:00', 'μg/m3'],
#  ['三義', '苗栗縣', '2', '2024-09-21 10:00', 'μg/m3'],
#  ['苗栗', '苗栗縣', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['頭份', '苗栗縣', '7', '2024-09-21 10:00', 'μg/m3'],
#  ['新竹', '新竹市', '3', '2024-09-21 10:00', 'μg/m3'],
#  ['竹東', '新竹縣', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['湖口', '新竹縣', '0', '2024-09-21 10:00', 'μg/m3'],
#  ['龍潭', '桃園市', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['平鎮', '桃園市', '4', '2024-09-21 10:00', 'μg/m3'],
#  ['觀音', '桃園市', '2', '2024-09-21 10:00', 'μg/m3'],
#  ['大園', '桃園市', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['桃園', '桃園市', '0', '2024-09-21 10:00', 'μg/m3'],
#  ['大同', '臺北市', '13', '2024-09-21 10:00', 'μg/m3'],
#  ['松山', '臺北市', '6', '2024-09-21 10:00', 'μg/m3'],
#  ['古亭', '臺北市', '6', '2024-09-21 10:00', 'μg/m3'],
#  ['萬華', '臺北市', '9', '2024-09-21 10:00', 'μg/m3'],
#  ['中山', '臺北市', '7', '2024-09-21 10:00', 'μg/m3'],
#  ['士林', '臺北市', '1', '2024-09-21 10:00', 'μg/m3'],
#  ['淡水', '新北市', '6', '2024-09-21 10:00', 'μg/m3'],
#  ['林口', '新北市', '1', '2024-09-21 10:00', 'μg/m3'],
#  ['菜寮', '新北市', '10', '2024-09-21 10:00', 'μg/m3'],
#  ['新莊', '新北市', '7', '2024-09-21 10:00', 'μg/m3'],
#  ['板橋', '新北市', '5', '2024-09-21 10:00', 'μg/m3'],
#  ['土城', '新北市', '4', '2024-09-21 10:00', 'μg/m3'],
#  ['新店', '新北市', '12', '2024-09-21 10:00', 'μg/m3'],
#  ['萬里', '新北市', '3', '2024-09-21 10:00', 'μg/m3'],
#  ['汐止', '新北市', '8', '2024-09-21 10:00', 'μg/m3'],
#  ['基隆', '基隆市', '5', '2024-09-21 10:00', 'μg/m3']]

# %%
import pandas as pd

# %%
datas=requests.get(url).json()["records"]
df=pd.DataFrame(datas)
df
# Out:
#    site county pm25  datacreationdate itemunit
# 0    大城    彰化縣    2  2024-09-21 10:00    μg/m3
# 1   富貴角    新北市    4  2024-09-21 10:00    μg/m3
# 2    麥寮    雲林縣    8  2024-09-21 10:00    μg/m3
# 3    關山    臺東縣    1  2024-09-21 10:00    μg/m3
# 4    馬公    澎湖縣    0  2024-09-21 10:00    μg/m3
# ..  ...    ...  ...               ...      ...
# 73   土城    新北市    4  2024-09-21 10:00    μg/m3
# 74   新店    新北市   12  2024-09-21 10:00    μg/m3
# 75   萬里    新北市    3  2024-09-21 10:00    μg/m3
# 76   汐止    新北市    8  2024-09-21 10:00    μg/m3
# 77   基隆    基隆市    5  2024-09-21 10:00    μg/m3
#
# [78 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   site              78 non-null     object
#  1   county            78 non-null     object
#  2   pm25              78 non-null     object
#  3   datacreationdate  78 non-null     object
#  4   itemunit          78 non-null     object
# dtypes: object(5)
# memory usage: 3.2+ KB

# %%
df["pm25"]=df["pm25"].apply(lambda x:eval(x))
df
# Out:
#    site county  pm25  datacreationdate itemunit
# 0    大城    彰化縣     2  2024-09-21 10:00    μg/m3
# 1   富貴角    新北市     4  2024-09-21 10:00    μg/m3
# 2    麥寮    雲林縣     8  2024-09-21 10:00    μg/m3
# 3    關山    臺東縣     1  2024-09-21 10:00    μg/m3
# 4    馬公    澎湖縣     0  2024-09-21 10:00    μg/m3
# ..  ...    ...   ...               ...      ...
# 73   土城    新北市     4  2024-09-21 10:00    μg/m3
# 74   新店    新北市    12  2024-09-21 10:00    μg/m3
# 75   萬里    新北市     3  2024-09-21 10:00    μg/m3
# 76   汐止    新北市     8  2024-09-21 10:00    μg/m3
# 77   基隆    基隆市     5  2024-09-21 10:00    μg/m3
#
# [78 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   site              78 non-null     object
#  1   county            78 non-null     object
#  2   pm25              78 non-null     int64
#  3   datacreationdate  78 non-null     object
#  4   itemunit          78 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 3.2+ KB

# %%
df.sort_values("pm25",ascending=False)
# Out:
#    site county  pm25  datacreationdate itemunit
# 5    金門    金門縣    21  2024-09-21 10:00    μg/m3
# 27   大寮    高雄市    13  2024-09-21 10:00    μg/m3
# 62   大同    臺北市    13  2024-09-21 10:00    μg/m3
# 74   新店    新北市    12  2024-09-21 10:00    μg/m3
# 6    馬祖    連江縣    12  2024-09-21 10:00    μg/m3
# ..  ...    ...   ...               ...      ...
# 20   屏東    屏東縣     0  2024-09-21 10:00    μg/m3
# 61   桃園    桃園市     0  2024-09-21 10:00    μg/m3
# 15   陽明    臺北市     0  2024-09-21 10:00    μg/m3
# 56   湖口    新竹縣     0  2024-09-21 10:00    μg/m3
# 4    馬公    澎湖縣     0  2024-09-21 10:00    μg/m3
#
# [78 rows x 5 columns]
